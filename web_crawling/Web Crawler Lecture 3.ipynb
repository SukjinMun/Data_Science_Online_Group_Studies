# %% [markdown]
# # Handling XML Format Data
# - local weather report rss:https://www.kma.go.kr/wid/queryDFSRSS.jsp?zone=4182025000

# %%
import requests

url = "https://www.kma.go.kr/wid/queryDFSRSS.jsp?zone=4182025000"
response = requests.get(url).text
response[:100]

#the returned text tells us that this data is a xml file
# Out:
# '<?xml version="1.0" encoding="UTF-8" ?>\n<rss version="2.0">\n<channel>\n<title>기상청 동네예보 웹서비스 - 경기도 가평군'

# %%
# transforming xml into a dictionary (xml to dictionary)
import xmltodict

# parse -> methodology that explains and transforms only the format of data information,
#          without changing it.
# 변수 response에 저장된 정보를 parsing 

data = xmltodict.parse(response)

# %%
# display list of keys for the dictionary for the data
# in this case, it only returns rss. we should further see whether there are any
# sub-key lists under rss

data.keys()
# Out:
# odict_keys(['rss'])

# %%
data['rss'].keys()
# Out:
# odict_keys(['@version', 'channel'])

# %%
data['rss']['channel'].keys()
# Out:
# odict_keys(['title', 'link', 'description', 'language', 'generator', 'pubDate', 'item'])

# %%
data['rss']['channel']['title']
# Out:
# '기상청 동네예보 웹서비스 - 경기도 가평군 가평읍 도표예보'

# %%
data['rss']

# 출력된 내용은 Dictionary의 종류 중 OrderedDict 형식
# OrderedDict: Unlike dictionary, OrderedDict displays information in accordance to order
# Order is usually important in XML files
# Out:
# OrderedDict([('@version', '2.0'),
#              ('channel',
#               OrderedDict([('title', '기상청 동네예보 웹서비스 - 경기도 가평군 가평읍 도표예보'),
#                            ('link', 'http://www.kma.go.kr/weather/main.jsp'),
#                            ('description', '동네예보 웹서비스'),
#                            ('language', 'ko'),
#                            ('generator', '동네예보'),
#                            ('pubDate', '2022년 03월 10일 (목)요일 17:00'),
#                            ('item',
#                             OrderedDict([('author', '기상청'),
#                                          ('category', '경기도 가평군 가평읍'),
#                                          ('title',
#                                           '동네예보(도표) : 경기도 가평군 가평읍 [X=69,Y=132]'),
#                                          ('link',
#                                           'http://www.kma.go.kr/weather/forecast/timeseries.jsp?searchType=INTEREST&dongCode=4182025000'),
#                                          ('guid',
#                                           'http://www.kma.go.kr/weather/forecast/timeseries.jsp?searchType=INTEREST&dongCode=4182025000'),
#                                          ('description',
#                                           OrderedDict([('header',
#                                                         OrderedDict([('tm',
#                                                                       '202203101700'),
#                                                                      ('ts',
#                                                                       '5'),
#                                                                      ('x',
#                                                                       '69'),
#                                                                      ('y',
#                                                                       '132')])),
#                                                        ('body',
#                                                         OrderedDict([('data',
#                                                                       [OrderedDict([('@seq',
#                                                                                      '0'),
#                                                                                     ('hour',
#                                                                                      '21'),
#                                                                                     ('day',
#                                                                                      '0'),
#                                                                                     ('temp',
#                                                                                      '6.0'),
#                                                                                     ('tmx',
#                                                                                      '-999.0'),
#                                                                                     ('tmn',
#                                                                                      '-999.0'),
#                                                                                     ('sky',
#                                                                                      '1'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '맑음'),
#                                                                                     ('wfEn',
#                                                                                      'Clear'),
#                                                                                     ('pop',
#                                                                                      '0'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '1.5'),
#                                                                                     ('wd',
#                                                                                      '6'),
#                                                                                     ('wdKor',
#                                                                                      '서'),
#                                                                                     ('wdEn',
#                                                                                      'W'),
#                                                                                     ('reh',
#                                                                                      '60'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '1'),
#                                                                                     ('hour',
#                                                                                      '24'),
#                                                                                     ('day',
#                                                                                      '0'),
#                                                                                     ('temp',
#                                                                                      '3.0'),
#                                                                                     ('tmx',
#                                                                                      '-999.0'),
#                                                                                     ('tmn',
#                                                                                      '-999.0'),
#                                                                                     ('sky',
#                                                                                      '1'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '맑음'),
#                                                                                     ('wfEn',
#                                                                                      'Clear'),
#                                                                                     ('pop',
#                                                                                      '0'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '1.3'),
#                                                                                     ('wd',
#                                                                                      '5'),
#                                                                                     ('wdKor',
#                                                                                      '남서'),
#                                                                                     ('wdEn',
#                                                                                      'SW'),
#                                                                                     ('reh',
#                                                                                      '70'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '2'),
#                                                                                     ('hour',
#                                                                                      '3'),
#                                                                                     ('day',
#                                                                                      '1'),
#                                                                                     ('temp',
#                                                                                      '1.0'),
#                                                                                     ('tmx',
#                                                                                      '19.0'),
#                                                                                     ('tmn',
#                                                                                      '0.0'),
#                                                                                     ('sky',
#                                                                                      '1'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '맑음'),
#                                                                                     ('wfEn',
#                                                                                      'Clear'),
#                                                                                     ('pop',
#                                                                                      '0'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '0.9'),
#                                                                                     ('wd',
#                                                                                      '5'),
#                                                                                     ('wdKor',
#                                                                                      '남서'),
#                                                                                     ('wdEn',
#                                                                                      'SW'),
#                                                                                     ('reh',
#                                                                                      '80'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '3'),
#                                                                                     ('hour',
#                                                                                      '6'),
#                                                                                     ('day',
#                                                                                      '1'),
#                                                                                     ('temp',
#                                                                                      '0.0'),
#                                                                                     ('tmx',
#                                                                                      '19.0'),
#                                                                                     ('tmn',
#                                                                                      '0.0'),
#                                                                                     ('sky',
#                                                                                      '3'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '구름 많음'),
#                                                                                     ('wfEn',
#                                                                                      'Mostly Cloudy'),
#                                                                                     ('pop',
#                                                                                      '20'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '0.8'),
#                                                                                     ('wd',
#                                                                                      '4'),
#                                                                                     ('wdKor',
#                                                                                      '남'),
#                                                                                     ('wdEn',
#                                                                                      'S'),
#                                                                                     ('reh',
#                                                                                      '85'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '4'),
#                                                                                     ('hour',
#                                                                                      '9'),
#                                                                                     ('day',
#                                                                                      '1'),
#                                                                                     ('temp',
#                                                                                      '4.0'),
#                                                                                     ('tmx',
#                                                                                      '19.0'),
#                                                                                     ('tmn',
#                                                                                      '0.0'),
#                                                                                     ('sky',
#                                                                                      '3'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '구름 많음'),
#                                                                                     ('wfEn',
#                                                                                      'Mostly Cloudy'),
#                                                                                     ('pop',
#                                                                                      '20'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '0.8'),
#                                                                                     ('wd',
#                                                                                      '5'),
#                                                                                     ('wdKor',
#                                                                                      '남서'),
#                                                                                     ('wdEn',
#                                                                                      'SW'),
#                                                                                     ('reh',
#                                                                                      '75'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '5'),
#                                                                                     ('hour',
#                                                                                      '12'),
#                                                                                     ('day',
#                                                                                      '1'),
#                                                                                     ('temp',
#                                                                                      '13.0'),
#                                                                                     ('tmx',
#                                                                                      '19.0'),
#                                                                                     ('tmn',
#                                                                                      '0.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '흐림'),
#                                                                                     ('wfEn',
#                                                                                      'Cloudy'),
#                                                                                     ('pop',
#                                                                                      '30'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '2.4000000000000004'),
#                                                                                     ('wd',
#                                                                                      '6'),
#                                                                                     ('wdKor',
#                                                                                      '서'),
#                                                                                     ('wdEn',
#                                                                                      'W'),
#                                                                                     ('reh',
#                                                                                      '55'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '6'),
#                                                                                     ('hour',
#                                                                                      '15'),
#                                                                                     ('day',
#                                                                                      '1'),
#                                                                                     ('temp',
#                                                                                      '18.0'),
#                                                                                     ('tmx',
#                                                                                      '19.0'),
#                                                                                     ('tmn',
#                                                                                      '0.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '흐림'),
#                                                                                     ('wfEn',
#                                                                                      'Cloudy'),
#                                                                                     ('pop',
#                                                                                      '30'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '3.0'),
#                                                                                     ('wd',
#                                                                                      '6'),
#                                                                                     ('wdKor',
#                                                                                      '서'),
#                                                                                     ('wdEn',
#                                                                                      'W'),
#                                                                                     ('reh',
#                                                                                      '40'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '7'),
#                                                                                     ('hour',
#                                                                                      '18'),
#                                                                                     ('day',
#                                                                                      '1'),
#                                                                                     ('temp',
#                                                                                      '16.0'),
#                                                                                     ('tmx',
#                                                                                      '19.0'),
#                                                                                     ('tmn',
#                                                                                      '0.0'),
#                                                                                     ('sky',
#                                                                                      '1'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '맑음'),
#                                                                                     ('wfEn',
#                                                                                      'Clear'),
#                                                                                     ('pop',
#                                                                                      '0'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '1.2000000000000002'),
#                                                                                     ('wd',
#                                                                                      '6'),
#                                                                                     ('wdKor',
#                                                                                      '서'),
#                                                                                     ('wdEn',
#                                                                                      'W'),
#                                                                                     ('reh',
#                                                                                      '45'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '8'),
#                                                                                     ('hour',
#                                                                                      '21'),
#                                                                                     ('day',
#                                                                                      '1'),
#                                                                                     ('temp',
#                                                                                      '9.0'),
#                                                                                     ('tmx',
#                                                                                      '19.0'),
#                                                                                     ('tmn',
#                                                                                      '0.0'),
#                                                                                     ('sky',
#                                                                                      '1'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '맑음'),
#                                                                                     ('wfEn',
#                                                                                      'Clear'),
#                                                                                     ('pop',
#                                                                                      '0'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '1.5'),
#                                                                                     ('wd',
#                                                                                      '6'),
#                                                                                     ('wdKor',
#                                                                                      '서'),
#                                                                                     ('wdEn',
#                                                                                      'W'),
#                                                                                     ('reh',
#                                                                                      '75'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '9'),
#                                                                                     ('hour',
#                                                                                      '24'),
#                                                                                     ('day',
#                                                                                      '1'),
#                                                                                     ('temp',
#                                                                                      '6.0'),
#                                                                                     ('tmx',
#                                                                                      '19.0'),
#                                                                                     ('tmn',
#                                                                                      '0.0'),
#                                                                                     ('sky',
#                                                                                      '1'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '맑음'),
#                                                                                     ('wfEn',
#                                                                                      'Clear'),
#                                                                                     ('pop',
#                                                                                      '0'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '0.6000000000000001'),
#                                                                                     ('wd',
#                                                                                      '6'),
#                                                                                     ('wdKor',
#                                                                                      '서'),
#                                                                                     ('wdEn',
#                                                                                      'W'),
#                                                                                     ('reh',
#                                                                                      '85'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '10'),
#                                                                                     ('hour',
#                                                                                      '3'),
#                                                                                     ('day',
#                                                                                      '2'),
#                                                                                     ('temp',
#                                                                                      '4.0'),
#                                                                                     ('tmx',
#                                                                                      '18.0'),
#                                                                                     ('tmn',
#                                                                                      '2.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '흐림'),
#                                                                                     ('wfEn',
#                                                                                      'Cloudy'),
#                                                                                     ('pop',
#                                                                                      '30'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '0.5'),
#                                                                                     ('wd',
#                                                                                      '2'),
#                                                                                     ('wdKor',
#                                                                                      '동'),
#                                                                                     ('wdEn',
#                                                                                      'E'),
#                                                                                     ('reh',
#                                                                                      '90'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '11'),
#                                                                                     ('hour',
#                                                                                      '6'),
#                                                                                     ('day',
#                                                                                      '2'),
#                                                                                     ('temp',
#                                                                                      '3.0'),
#                                                                                     ('tmx',
#                                                                                      '18.0'),
#                                                                                     ('tmn',
#                                                                                      '2.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '흐림'),
#                                                                                     ('wfEn',
#                                                                                      'Cloudy'),
#                                                                                     ('pop',
#                                                                                      '30'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '1.0'),
#                                                                                     ('wd',
#                                                                                      '2'),
#                                                                                     ('wdKor',
#                                                                                      '동'),
#                                                                                     ('wdEn',
#                                                                                      'E'),
#                                                                                     ('reh',
#                                                                                      '95'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '12'),
#                                                                                     ('hour',
#                                                                                      '9'),
#                                                                                     ('day',
#                                                                                      '2'),
#                                                                                     ('temp',
#                                                                                      '6.0'),
#                                                                                     ('tmx',
#                                                                                      '18.0'),
#                                                                                     ('tmn',
#                                                                                      '2.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
# ...
#                                                                                     ('wd',
#                                                                                      '3'),
#                                                                                     ('wdKor',
#                                                                                      '남동'),
#                                                                                     ('wdEn',
#                                                                                      'SE'),
#                                                                                     ('reh',
#                                                                                      '70'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '14'),
#                                                                                     ('hour',
#                                                                                      '15'),
#                                                                                     ('day',
#                                                                                      '2'),
#                                                                                     ('temp',
#                                                                                      '16.0'),
#                                                                                     ('tmx',
#                                                                                      '18.0'),
#                                                                                     ('tmn',
#                                                                                      '2.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '흐림'),
#                                                                                     ('wfEn',
#                                                                                      'Cloudy'),
#                                                                                     ('pop',
#                                                                                      '30'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '1.6'),
#                                                                                     ('wd',
#                                                                                      '4'),
#                                                                                     ('wdKor',
#                                                                                      '남'),
#                                                                                     ('wdEn',
#                                                                                      'S'),
#                                                                                     ('reh',
#                                                                                      '70'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '15'),
#                                                                                     ('hour',
#                                                                                      '18'),
#                                                                                     ('day',
#                                                                                      '2'),
#                                                                                     ('temp',
#                                                                                      '15.0'),
#                                                                                     ('tmx',
#                                                                                      '18.0'),
#                                                                                     ('tmn',
#                                                                                      '2.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '0'),
#                                                                                     ('wfKor',
#                                                                                      '흐림'),
#                                                                                     ('wfEn',
#                                                                                      'Cloudy'),
#                                                                                     ('pop',
#                                                                                      '30'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '1.7000000000000002'),
#                                                                                     ('wd',
#                                                                                      '4'),
#                                                                                     ('wdKor',
#                                                                                      '남'),
#                                                                                     ('wdEn',
#                                                                                      'S'),
#                                                                                     ('reh',
#                                                                                      '75'),
#                                                                                     ('r06',
#                                                                                      '0.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '16'),
#                                                                                     ('hour',
#                                                                                      '21'),
#                                                                                     ('day',
#                                                                                      '2'),
#                                                                                     ('temp',
#                                                                                      '12.0'),
#                                                                                     ('tmx',
#                                                                                      '18.0'),
#                                                                                     ('tmn',
#                                                                                      '2.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '1'),
#                                                                                     ('wfKor',
#                                                                                      '비'),
#                                                                                     ('wfEn',
#                                                                                      'Rain'),
#                                                                                     ('pop',
#                                                                                      '60'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '1.9000000000000001'),
#                                                                                     ('wd',
#                                                                                      '4'),
#                                                                                     ('wdKor',
#                                                                                      '남'),
#                                                                                     ('wdEn',
#                                                                                      'S'),
#                                                                                     ('reh',
#                                                                                      '90'),
#                                                                                     ('r06',
#                                                                                      '3.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')]),
#                                                                        OrderedDict([('@seq',
#                                                                                      '17'),
#                                                                                     ('hour',
#                                                                                      '24'),
#                                                                                     ('day',
#                                                                                      '2'),
#                                                                                     ('temp',
#                                                                                      '11.0'),
#                                                                                     ('tmx',
#                                                                                      '18.0'),
#                                                                                     ('tmn',
#                                                                                      '2.0'),
#                                                                                     ('sky',
#                                                                                      '4'),
#                                                                                     ('pty',
#                                                                                      '1'),
#                                                                                     ('wfKor',
#                                                                                      '비'),
#                                                                                     ('wfEn',
#                                                                                      'Rain'),
#                                                                                     ('pop',
#                                                                                      '60'),
#                                                                                     ('r12',
#                                                                                      '0.0'),
#                                                                                     ('s12',
#                                                                                      '0.0'),
#                                                                                     ('ws',
#                                                                                      '2.2'),
#                                                                                     ('wd',
#                                                                                      '4'),
#                                                                                     ('wdKor',
#                                                                                      '남'),
#                                                                                     ('wdEn',
#                                                                                      'S'),
#                                                                                     ('reh',
#                                                                                      '90'),
#                                                                                     ('r06',
#                                                                                      '3.0'),
#                                                                                     ('s06',
#                                                                                      '0.0')])])]))]))]))]))])

# %%
# rss - channel - item - decription - body - data 에서
# hour, day, temp, ..., wfKor

data['rss']['channel']['item']['description']['body']['data'].keys()

# AttributeError: List는 keys 메서드를 사용할 수 없음
# data['rss']['channel']['item']['description']['body']['data']  --> It is a list (a list of dictionaries to be exact)
# data는 현재 14개의 List 형태로 구성되어 있음
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-11a7b78da9df> in <module>
#       2 # hour, day, temp, ..., wfKor
#       3
# ----> 4 data['rss']['channel']['item']['description']['body']['data'].keys()
#       5
#       6 # AttributeError: List는 keys 메서드를 사용할 수 없음
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
weather_list = data['rss']['channel']['item']['description']['body']['data']
weather_list[0].keys()
# Out:
# odict_keys(['@seq', 'hour', 'day', 'temp', 'tmx', 'tmn', 'sky', 'pty', 'wfKor', 'wfEn', 'pop', 'r12', 's12', 'ws', 'wd', 'wdKor', 'wdEn', 'reh', 'r06', 's06'])

# %%
weather_list[0]['wfKor']

# weather_list는 List이고 그 안에 Dictionary들이 들어 있음 -> Data Frame으로 변환할 수 있음
# Out:
# '맑음'

# %%
import pandas as pd
pd.DataFrame(weather_list)
# Out:
#    @seq hour day  temp     tmx     tmn sky pty  wfKor           wfEn pop  r12  \
# 0     0   21   0   6.0  -999.0  -999.0   1   0     맑음          Clear   0  0.0
# 1     1   24   0   3.0  -999.0  -999.0   1   0     맑음          Clear   0  0.0
# 2     2    3   1   1.0    19.0     0.0   1   0     맑음          Clear   0  0.0
# 3     3    6   1   0.0    19.0     0.0   3   0  구름 많음  Mostly Cloudy  20  0.0
# 4     4    9   1   4.0    19.0     0.0   3   0  구름 많음  Mostly Cloudy  20  0.0
# 5     5   12   1  13.0    19.0     0.0   4   0     흐림         Cloudy  30  0.0
# 6     6   15   1  18.0    19.0     0.0   4   0     흐림         Cloudy  30  0.0
# 7     7   18   1  16.0    19.0     0.0   1   0     맑음          Clear   0  0.0
# 8     8   21   1   9.0    19.0     0.0   1   0     맑음          Clear   0  0.0
# 9     9   24   1   6.0    19.0     0.0   1   0     맑음          Clear   0  0.0
# 10   10    3   2   4.0    18.0     2.0   4   0     흐림         Cloudy  30  0.0
# 11   11    6   2   3.0    18.0     2.0   4   0     흐림         Cloudy  30  0.0
# 12   12    9   2   6.0    18.0     2.0   4   0     흐림         Cloudy  30  0.0
# 13   13   12   2  13.0    18.0     2.0   4   0     흐림         Cloudy  30  0.0
# 14   14   15   2  16.0    18.0     2.0   4   0     흐림         Cloudy  30  0.0
# 15   15   18   2  15.0    18.0     2.0   4   0     흐림         Cloudy  30  0.0
# 16   16   21   2  12.0    18.0     2.0   4   1      비           Rain  60  0.0
# 17   17   24   2  11.0    18.0     2.0   4   1      비           Rain  60  0.0
#
#     s12                  ws wd wdKor wdEn reh  r06  s06
# 0   0.0                 1.5  6     서    W  60  0.0  0.0
# 1   0.0                 1.3  5    남서   SW  70  0.0  0.0
# 2   0.0                 0.9  5    남서   SW  80  0.0  0.0
# 3   0.0                 0.8  4     남    S  85  0.0  0.0
# 4   0.0                 0.8  5    남서   SW  75  0.0  0.0
# 5   0.0  2.4000000000000004  6     서    W  55  0.0  0.0
# 6   0.0                 3.0  6     서    W  40  0.0  0.0
# 7   0.0  1.2000000000000002  6     서    W  45  0.0  0.0
# 8   0.0                 1.5  6     서    W  75  0.0  0.0
# 9   0.0  0.6000000000000001  6     서    W  85  0.0  0.0
# 10  0.0                 0.5  2     동    E  90  0.0  0.0
# 11  0.0                 1.0  2     동    E  95  0.0  0.0
# 12  0.0  1.2000000000000002  3    남동   SE  85  0.0  0.0
# 13  0.0                 1.5  3    남동   SE  70  0.0  0.0
# 14  0.0                 1.6  4     남    S  70  0.0  0.0
# 15  0.0  1.7000000000000002  4     남    S  75  0.0  0.0
# 16  0.0  1.9000000000000001  4     남    S  90  3.0  0.0
# 17  0.0                 2.2  4     남    S  90  3.0  0.0

# %%
pd.DataFrame(weather_list).to_csv('weather.csv', index=False)

# %%
pd.DataFrame(weather_list).to_csv('weather.csv', index=False, encoding='utf-8-sig')

# 한글이 깨져서 저장됨
# 엑셀로 열었을 때 깨지고, 메모장으로 열었을 때 안깨짐 -> 즉 데이터가 손상된 것은 아님
# 글자 깨짐이란 저장하는 방식과 읽어들이는 방식이 다를 때 발생
# 저장하는 방식과 읽어들이는 방식을 맞게 하면 해결!
# 대표적인 encoding 방식: euc-kr, latin, cp949, iso.., utf-8
# https://docs.python.org/ko/3/library/codecs.html

# %%
# 'encoding=' 옵션에 넣을 수 있는 경우의 수를 가져오기

path = 'https://docs.python.org/ko/3/library/codecs.html'


# pd.read_html method returns the list of tables in the html file

tables = pd.read_html(path)

# %%
# number of tables in the html file

len(tables)
# Out:
# 8

# %%
# Fourth table that is listed in the imported html

tables[4]
# Out:
#            코덱                      별칭               언어
# 0       ascii           646, us-ascii               영어
# 1        big5         big5-tw, csbig5           중국어 번체
# 2   big5hkscs       big5-hkscs, hkscs           중국어 번체
# 3       cp037          IBM037, IBM039               영어
# 4       cp273   273, IBM273, csIBM273  독일어 버전 3.4에 추가.
# ..        ...                     ...              ...
# 92  utf_16_be                UTF-16BE            모든 언어
# 93  utf_16_le                UTF-16LE            모든 언어
# 94      utf_7   U7, unicode-1-1-utf-7            모든 언어
# 95      utf_8  U8, UTF, utf8, cp65001            모든 언어
# 96  utf_8_sig                     NaN            모든 언어
#
# [97 rows x 3 columns]

# %%
# access first column values for the table

tables[4]['코덱']
# Out:
# 0         ascii
# 1          big5
# 2     big5hkscs
# 3         cp037
# 4         cp273
#         ...
# 92    utf_16_be
# 93    utf_16_le
# 94        utf_7
# 95        utf_8
# 96    utf_8_sig
# Name: 코덱, Length: 97, dtype: object

# %% [markdown]
# # Google News: https://news.google.com/rss/search?q=펭수&hl=ko&gl=KR&ceid=KR%3Ako

# %%
import requests
import xmltodict

url = "https://news.google.com/rss/search?q=펭수&hl=ko&gl=KR&ceid=KR%3Ako"
response = requests.get(url).text
gnews_data = xmltodict.parse(response)

gnews_list = gnews_data['rss']['channel']['item']
gnews_list[2].keys()

#gnews_list is a list that has dictionaries inside
# Out:
# odict_keys(['title', 'link', 'guid', 'pubDate', 'description', 'source'])

# %%
import pandas as pd

pd.DataFrame(gnews_list)
# Out:
#                                                 title  \
# 0        EBS 사장 퇴임식서 포착된 ‘존재감 폭발’ 펭수 “김명중 가지마” - 세계일보
# 1          이재명, 홍대서 '펭수 성대모사'하며 청년 격려 [쿡정치 포토] - 쿠키뉴스
# 2                         펭수를 성공시킨 '퍼스트 펭귄' 정신 - 단비뉴스
# 3            펭수, 권익위 국민콜110 특별상담사로 활약…고충·보람 느껴 - 아주경제
# 4                  붱철 조교, 펭수 잇는 EBS 간판 스타 되나? - 머니투데이
# ..                                                ...
# 95  CU, 펭수 이미지 무단사용 논란… "바로 삭제, 소통 부재로 오해" - 조선비즈 ...
# 96  펭수, 카카오 이적? `찐경규`-`펭TV` 이색 트레이드…모르모트PD와 케미 기대 ...
# 97                     펭수, 이번엔 힙합 가수 된다 - 조선비즈 - 조선비즈
# 98  [뮤지컬] 비틀쥬스 X 펭수, 100만 뷰…화제의 특급 콜라보 공개 - 조선일보 -...
# 99              [단독] 펭수의 무한변신 학계도 주목… "인간 그자체" - 세계일보
#
#                                                  link  \
# 0             https://m.segye.com/view/20220313507298
# 1   https://www.kukinews.com/newsView/kuk202202170231
# 2   http://m.danbinews.com/news/articleView.html?i...
# 3        https://m.ajunews.com/view/20211126092436394
# 4   https://news.mt.co.kr/mtview.php?no=2021120909...
# ..                                                ...
# 95  https://biz.chosun.com/site/data/html_dir/2020...
# 96  https://www.mk.co.kr/star/hot-issues/view/2020...
# 97  https://biz.chosun.com/site/data/html_dir/2020...
# 98  https://www.chosun.com/culture-life/culture_ge...
# 99             http://m.segye.com/view/20200528514377
#
#                                                  guid  \
# 0   {'@isPermaLink': 'false', '#text': 'CBMiJ2h0dH...
# 1   {'@isPermaLink': 'false', '#text': 'CBMiMWh0dH...
# 2   {'@isPermaLink': 'false', '#text': 'CBMiOGh0dH...
# 3   {'@isPermaLink': 'false', '#text': 'CBMiLGh0dH...
# 4   {'@isPermaLink': 'false', '#text': 'CBMiN2h0dH...
# ..                                                ...
# 95  {'@isPermaLink': 'false', '#text': 'CBMiR2h0dH...
# 96  {'@isPermaLink': 'false', '#text': 'CBMiOmh0dH...
# 97  {'@isPermaLink': 'false', '#text': 'CBMiR2h0dH...
# 98  {'@isPermaLink': 'false', '#text': 'CBMiWmh0dH...
# 99  {'@isPermaLink': 'false', '#text': 'CBMiJmh0dH...
#
#                           pubDate  \
# 0   Sun, 13 Mar 2022 06:49:03 GMT
# 1   Fri, 18 Feb 2022 08:00:00 GMT
# 2   Wed, 27 Oct 2021 07:00:00 GMT
# 3   Fri, 26 Nov 2021 08:00:00 GMT
# 4   Thu, 09 Dec 2021 08:00:00 GMT
# ..                            ...
# 95  Mon, 13 Jan 2020 08:00:00 GMT
# 96  Mon, 23 Nov 2020 08:00:00 GMT
# 97  Fri, 17 Apr 2020 07:00:00 GMT
# 98  Tue, 01 Jun 2021 07:00:00 GMT
# 99  Fri, 29 May 2020 07:00:00 GMT
#
#                                           description  \
# 0   <a href="https://m.segye.com/view/202203135072...
# 1   <a href="https://www.kukinews.com/newsView/kuk...
# 2   <a href="http://m.danbinews.com/news/articleVi...
# 3   <a href="https://m.ajunews.com/view/2021112609...
# 4   <a href="https://news.mt.co.kr/mtview.php?no=2...
# ..                                                ...
# 95  <a href="https://biz.chosun.com/site/data/html...
# 96  <a href="https://www.mk.co.kr/star/hot-issues/...
# 97  <a href="https://biz.chosun.com/site/data/html...
# 98  <a href="https://www.chosun.com/culture-life/c...
# 99  <a href="http://m.segye.com/view/2020052851437...
#
#                                                source
# 0    {'@url': 'https://m.segye.com', '#text': '세계일보'}
# 1   {'@url': 'https://www.kukinews.com', '#text': ...
# 2   {'@url': 'http://m.danbinews.com', '#text': '단...
# 3   {'@url': 'https://m.ajunews.com', '#text': '아주...
# 4   {'@url': 'https://news.mt.co.kr', '#text': '머니...
# ..                                                ...
# 95  {'@url': 'https://biz.chosun.com', '#text': '조...
# 96  {'@url': 'https://www.mk.co.kr', '#text': '매일경제'}
# 97  {'@url': 'https://biz.chosun.com', '#text': '조...
# 98  {'@url': 'https://www.chosun.com', '#text': 'T...
# 99    {'@url': 'http://m.segye.com', '#text': '세계일보'}
#
# [100 rows x 6 columns]

# %%
# Q) 사용자가 입력한 키워드에 대한 뉴스 정보를 파일에 저장하세요.
# A)

def news_get(arg):
    url = f'https://news.google.com/rss/search?q={arg}&hl=ko&gl=KR&ceid=KR%3Ako'
    response = requests.get(url).text
    news_data = xmltodict.parse(response)
    news_list = news_data['rss']['channel']['item']
    pd.DataFrame(news_list).to_csv(arg+'.csv', index=False, encoding='utf-8-sig')

news_get('아기상어') # 아기상어.csv

# %% [markdown]
# ## BeautifulSoup
# #### -module that imports or analyzes necessary data from HTML, XML
# #### -document: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# #### -installation: pip install beautifulsoup4
#
# #### essentially xmltodict -> BeautifulSoup this time (unlike dictionary's values and keys, this time we assess through tags, <>) as above
# #### information in html are not stored in dictionaries, but they are stored in tags, so BeautifulSoup should be used to crawl the data in HTML

# %% [markdown]
# ## Local Weather Report rss - BeautifulSoup Application
# #### weather report rss: http://www.kma.go.kr/wid/queryDFSRSS.jsp?zone=1111061500

# %%
# xmltodict method

import requests
import xmltodict

url = 'http://www.kma.go.kr/wid/queryDFSRSS.jsp?zone=1111061500'
response = requests.get(url).text
data = xmltodict.parse(response)

weather_list = data['rss']['channel']['item']['description']['body']['data']
weather_list[0]['wfKor']
# Out:
# '흐림'

# %%
# BeautifulSoup method

import requests
import bs4

url = 'http://www.kma.go.kr/wid/queryDFSRSS.jsp?zone=1111061500'
response = requests.get(url).text

# convert xml document into a BeautifulSoup class object
# we also have to store the document parser (program that executes parsing 
# that analyzes grammatical relations within the document), and
# in this case, 'xml' is the parser we need.
data = bs4.BeautifulSoup(response, features='xml')

# "find()" searches the very fist input tag (so in order to search all tags, one must use .find_all() function)
# not in the form of dictionary tag but in the tag form
# .text gets rid of the tag
print(data.find('wfKor'))
print(data.find('wfKor').text)
print(type(data))
# Out:
# <wfKor>흐림</wfKor>
# 흐림
# <class 'bs4.BeautifulSoup'>

# %%
# Finding the data in the desired position
# ex) body - 두 번째 data - wfKor

# .find('body') -> tag 개념으로 해석한 전체 데이터에서 body 태그를 하나 찾음
# .find_all('data') -> body 태그 안을 대상으로 data 태그를 전부 찾음
# find_all()은 전부 찾기 때문에 결과가 여러 개 -> 결과를 List로 표현
# [1].find('wfKor') -> 두 번째 index 의 data 태그 안에서 wfKor 태그를 찾음
# .text -> tag를 제거
data.find('body').find_all('data')[0].find('wfKor').text
# Out:
# '흐림'

# %%
# find all "data" tags (here data tags mean the <data>s within the xml file, don't get confused)

weather_list = data.find('body').find_all('data')
weather_list
# Out:
# [<data seq="0">
#  <hour>18</hour>
#  <day>0</day>
#  <temp>11.0</temp>
#  <tmx>-999.0</tmx>
#  <tmn>-999.0</tmn>
#  <sky>4</sky>
#  <pty>0</pty>
#  <wfKor>흐림</wfKor>
#  <wfEn>Cloudy</wfEn>
#  <pop>30</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.6</ws>
#  <wd>5</wd>
#  <wdKor>남서</wdKor>
#  <wdEn>SW</wdEn>
#  <reh>65</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="1">
#  <hour>21</hour>
#  <day>0</day>
#  <temp>10.0</temp>
#  <tmx>-999.0</tmx>
#  <tmn>-999.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>20</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.2000000000000002</ws>
#  <wd>4</wd>
#  <wdKor>남</wdKor>
#  <wdEn>S</wdEn>
#  <reh>70</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="2">
#  <hour>24</hour>
#  <day>0</day>
#  <temp>9.0</temp>
#  <tmx>-999.0</tmx>
#  <tmn>-999.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>20</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.3</ws>
#  <wd>4</wd>
#  <wdKor>남</wdKor>
#  <wdEn>S</wdEn>
#  <reh>70</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="3">
#  <hour>3</hour>
#  <day>1</day>
#  <temp>8.0</temp>
#  <tmx>19.0</tmx>
#  <tmn>7.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>20</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.3</ws>
#  <wd>3</wd>
#  <wdKor>남동</wdKor>
#  <wdEn>SE</wdEn>
#  <reh>70</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="4">
#  <hour>6</hour>
#  <day>1</day>
#  <temp>8.0</temp>
#  <tmx>19.0</tmx>
#  <tmn>7.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>10</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.7000000000000002</ws>
#  <wd>3</wd>
#  <wdKor>남동</wdKor>
#  <wdEn>SE</wdEn>
#  <reh>75</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="5">
#  <hour>9</hour>
#  <day>1</day>
#  <temp>10.0</temp>
#  <tmx>19.0</tmx>
#  <tmn>7.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>20</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>2.7</ws>
#  <wd>3</wd>
#  <wdKor>남동</wdKor>
#  <wdEn>SE</wdEn>
#  <reh>65</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="6">
#  <hour>12</hour>
#  <day>1</day>
#  <temp>16.0</temp>
#  <tmx>19.0</tmx>
#  <tmn>7.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>20</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>2.8000000000000003</ws>
#  <wd>4</wd>
#  <wdKor>남</wdKor>
#  <wdEn>S</wdEn>
#  <reh>45</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="7">
#  <hour>15</hour>
#  <day>1</day>
#  <temp>18.0</temp>
#  <tmx>19.0</tmx>
#  <tmn>7.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>20</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>3.1</ws>
#  <wd>4</wd>
#  <wdKor>남</wdKor>
#  <wdEn>S</wdEn>
#  <reh>40</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="8">
#  <hour>18</hour>
#  <day>1</day>
#  <temp>17.0</temp>
#  <tmx>19.0</tmx>
#  <tmn>7.0</tmn>
#  <sky>4</sky>
#  <pty>0</pty>
#  <wfKor>흐림</wfKor>
#  <wfEn>Cloudy</wfEn>
#  <pop>30</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.2000000000000002</ws>
#  <wd>4</wd>
#  <wdKor>남</wdKor>
#  <wdEn>S</wdEn>
#  <reh>50</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="9">
#  <hour>21</hour>
#  <day>1</day>
#  <temp>15.0</temp>
#  <tmx>19.0</tmx>
#  <tmn>7.0</tmn>
#  <sky>4</sky>
#  <pty>0</pty>
#  <wfKor>흐림</wfKor>
#  <wfEn>Cloudy</wfEn>
#  <pop>30</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>2.1</ws>
#  <wd>3</wd>
#  <wdKor>남동</wdKor>
#  <wdEn>SE</wdEn>
#  <reh>60</reh>
#  <r06>4.8999996</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="10">
#  <hour>24</hour>
#  <day>1</day>
#  <temp>14.0</temp>
#  <tmx>19.0</tmx>
#  <tmn>7.0</tmn>
#  <sky>4</sky>
#  <pty>1</pty>
#  <wfKor>비</wfKor>
#  <wfEn>Rain</wfEn>
#  <pop>60</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>3.9000000000000004</ws>
#  <wd>2</wd>
#  <wdKor>동</wdKor>
#  <wdEn>E</wdEn>
#  <reh>80</reh>
#  <r06>4.8999996</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="11">
#  <hour>3</hour>
#  <day>2</day>
#  <temp>14.0</temp>
#  <tmx>17.0</tmx>
#  <tmn>10.0</tmn>
#  <sky>4</sky>
#  <pty>1</pty>
#  <wfKor>비</wfKor>
#  <wfEn>Rain</wfEn>
#  <pop>66</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>3.6</ws>
#  <wd>3</wd>
#  <wdKor>남동</wdKor>
#  <wdEn>SE</wdEn>
#  <reh>80</reh>
#  <r06>26.400002</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="12">
#  <hour>6</hour>
#  <day>2</day>
#  <temp>13.0</temp>
#  <tmx>17.0</tmx>
#  <tmn>10.0</tmn>
#  <sky>4</sky>
#  <pty>1</pty>
#  <wfKor>비</wfKor>
#  <wfEn>Rain</wfEn>
#  <pop>90</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.3</ws>
#  <wd>3</wd>
#  <wdKor>남동</wdKor>
#  <wdEn>SE</wdEn>
#  <reh>85</reh>
#  <r06>26.400002</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="13">
#  <hour>9</hour>
#  <day>2</day>
#  <temp>10.0</temp>
#  <tmx>17.0</tmx>
#  <tmn>10.0</tmn>
#  <sky>4</sky>
#  <pty>1</pty>
#  <wfKor>비</wfKor>
#  <wfEn>Rain</wfEn>
#  <pop>75</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>0.8</ws>
#  <wd>7</wd>
#  <wdKor>북서</wdKor>
#  <wdEn>NW</wdEn>
#  <reh>90</reh>
#  <r06>6.4</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="14">
#  <hour>12</hour>
#  <day>2</day>
#  <temp>14.0</temp>
#  <tmx>17.0</tmx>
#  <tmn>10.0</tmn>
#  <sky>4</sky>
#  <pty>0</pty>
#  <wfKor>흐림</wfKor>
#  <wfEn>Cloudy</wfEn>
#  <pop>30</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>4.5</ws>
#  <wd>0</wd>
#  <wdKor>북</wdKor>
#  <wdEn>N</wdEn>
#  <reh>75</reh>
#  <r06>6.4</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="15">
#  <hour>15</hour>
#  <day>2</day>
#  <temp>17.0</temp>
#  <tmx>17.0</tmx>
#  <tmn>10.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>20</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>4.1000000000000005</ws>
#  <wd>0</wd>
#  <wdKor>북</wdKor>
#  <wdEn>N</wdEn>
#  <reh>55</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="16">
#  <hour>18</hour>
#  <day>2</day>
#  <temp>15.0</temp>
#  <tmx>17.0</tmx>
#  <tmn>10.0</tmn>
#  <sky>4</sky>
#  <pty>0</pty>
#  <wfKor>흐림</wfKor>
#  <wfEn>Cloudy</wfEn>
#  <pop>30</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.9000000000000001</ws>
#  <wd>0</wd>
#  <wdKor>북</wdKor>
#  <wdEn>N</wdEn>
#  <reh>55</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="17">
#  <hour>21</hour>
#  <day>2</day>
#  <temp>11.0</temp>
#  <tmx>17.0</tmx>
#  <tmn>10.0</tmn>
#  <sky>3</sky>
#  <pty>0</pty>
#  <wfKor>구름 많음</wfKor>
#  <wfEn>Mostly Cloudy</wfEn>
#  <pop>20</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>1.3</ws>
#  <wd>2</wd>
#  <wdKor>동</wdKor>
#  <wdEn>E</wdEn>
#  <reh>65</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>,
#  <data seq="18">
#  <hour>24</hour>
#  <day>2</day>
#  <temp>9.0</temp>
#  <tmx>17.0</tmx>
#  <tmn>10.0</tmn>
#  <sky>4</sky>
#  <pty>0</pty>
#  <wfKor>흐림</wfKor>
#  <wfEn>Cloudy</wfEn>
#  <pop>30</pop>
#  <r12>0.0</r12>
#  <s12>0.0</s12>
#  <ws>0.6000000000000001</ws>
#  <wd>2</wd>
#  <wdKor>동</wdKor>
#  <wdEn>E</wdEn>
#  <reh>60</reh>
#  <r06>0.0</r06>
#  <s06>0.0</s06>
#  </data>]

# %%
import pandas as pd
weather_data = []

for x in weather_list:
    day = x.find('day').text
    hour = x.find('hour').text
    wfKor = x.find('wfKor').text
    weather_dict = {'day':day, 'hour':hour, 'wfKor':wfKor}
    # append the data from the dictionary into the previously created empty list, weather_data 
    weather_data.append(weather_dict)

pd.DataFrame(weather_data).to_csv('weather.csv', index=False, encoding='utf-8-sig')

# print dataframe just for visualization purpose
df = pd.DataFrame(weather_data)
df
# Out:
#    day hour  wfKor
# 0    0   18     흐림
# 1    0   21  구름 많음
# 2    0   24  구름 많음
# 3    1    3  구름 많음
# 4    1    6  구름 많음
# 5    1    9  구름 많음
# 6    1   12  구름 많음
# 7    1   15  구름 많음
# 8    1   18     흐림
# 9    1   21     흐림
# 10   1   24      비
# 11   2    3      비
# 12   2    6      비
# 13   2    9      비
# 14   2   12     흐림
# 15   2   15  구름 많음
# 16   2   18     흐림
# 17   2   21  구름 많음
# 18   2   24     흐림
